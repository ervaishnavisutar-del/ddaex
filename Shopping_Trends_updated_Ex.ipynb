# %% [markdown]
# <a href="https://colab.research.google.com/github/ervaishnavisutar-del/ddaex/blob/main/Shopping_Trends_updated_Ex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("shopping_trends_updated.csv")

# %%
df.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
#    Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0        Express              Yes             Yes                  14
# 1        Express              Yes             Yes                   2
# 2  Free Shipping              Yes             Yes                  23
# 3   Next Day Air              Yes             Yes                  49
# 4  Free Shipping              Yes             Yes                  31
#
#   Payment Method Frequency of Purchases
# 0          Venmo            Fortnightly
# 1           Cash            Fortnightly
# 2    Credit Card                 Weekly
# 3         PayPal                 Weekly
# 4         PayPal               Annually

# %%
df.shape
# Out:
# (3900, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   object
#  3   Item Purchased          3900 non-null   object
#  4   Category                3900 non-null   object
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   object
#  7   Size                    3900 non-null   object
#  8   Color                   3900 non-null   object
#  9   Season                  3900 non-null   object
#  10  Review Rating           3900 non-null   float64
#  11  Subscription Status     3900 non-null   object
#  12  Shipping Type           3900 non-null   object
#  13  Discount Applied        3900 non-null   object
#  14  Promo Code Used         3900 non-null   object
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   object
#  17  Frequency of Purchases  3900 non-null   object
# dtypes: float64(1), int64(4), object(13)
# memory usage: 548.6+ KB

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df["Age_Group"]=pd.cut(
    df["Age"],
    bins=[0,25,40,60,100],
    labels=["Young","Adult","Middle","Senior"]
)
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        90   Rhode Island    M     Maroon  Spring
# 4                        49         Oregon    M  Turquoise  Spring
# ...                     ...            ...  ...        ...     ...
# 3895                     28       Virginia    L  Turquoise  Summer
# 3896                     49           Iowa    L      White  Spring
# 3897                     33     New Jersey    L      Green  Spring
# 3898                     77      Minnesota    S      Brown  Summer
# 3899                     81     California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0               3.1                 Yes         Express              Yes
# 1               3.1                 Yes         Express              Yes
# 2               3.1                 Yes   Free Shipping              Yes
# 3               3.5                 Yes    Next Day Air              Yes
# 4               2.7                 Yes   Free Shipping              Yes
# ...             ...                 ...             ...              ...
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# 3897            2.9                  No        Standard               No
# 3898            3.8                  No         Express               No
# 3899            3.1                  No    Store Pickup               No
#
#      Promo Code Used  Previous Purchases Payment Method  \
# 0                Yes                  14          Venmo
# 1                Yes                   2           Cash
# 2                Yes                  23    Credit Card
# 3                Yes                  49         PayPal
# 4                Yes                  31         PayPal
# ...              ...                 ...            ...
# 3895              No                  32          Venmo
# 3896              No                  41  Bank Transfer
# 3897              No                  24          Venmo
# 3898              No                  24          Venmo
# 3899              No                  33          Venmo
#
#      Frequency of Purchases Age_Group
# 0               Fortnightly    Middle
# 1               Fortnightly     Young
# 2                    Weekly    Middle
# 3                    Weekly     Young
# 4                  Annually    Middle
# ...                     ...       ...
# 3895                 Weekly     Adult
# 3896              Bi-Weekly    Middle
# 3897              Quarterly    Middle
# 3898                 Weekly    Middle
# 3899              Quarterly    Middle
#
# [3900 rows x 19 columns]

# %%
def Amount_Category (amount):
    if amount <= 30:
        return"Low"
    elif amount <= 70:
        return "Medium"
    else:
      return"High"
df["Amount_Category"]=df["Purchase Amount (USD)"].apply(Amount_Category)
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# 2                        73  Massachusetts    S     Maroon  Spring
# 3                        90   Rhode Island    M     Maroon  Spring
# 4                        49         Oregon    M  Turquoise  Spring
# ...                     ...            ...  ...        ...     ...
# 3895                     28       Virginia    L  Turquoise  Summer
# 3896                     49           Iowa    L      White  Spring
# 3897                     33     New Jersey    L      Green  Spring
# 3898                     77      Minnesota    S      Brown  Summer
# 3899                     81     California    M      Beige  Spring
#
#       Review Rating Subscription Status   Shipping Type Discount Applied  \
# 0               3.1                 Yes         Express              Yes
# 1               3.1                 Yes         Express              Yes
# 2               3.1                 Yes   Free Shipping              Yes
# 3               3.5                 Yes    Next Day Air              Yes
# 4               2.7                 Yes   Free Shipping              Yes
# ...             ...                 ...             ...              ...
# 3895            4.2                  No  2-Day Shipping               No
# 3896            4.5                  No    Store Pickup               No
# 3897            2.9                  No        Standard               No
# 3898            3.8                  No         Express               No
# 3899            3.1                  No    Store Pickup               No
#
#      Promo Code Used  Previous Purchases Payment Method  \
# 0                Yes                  14          Venmo
# 1                Yes                   2           Cash
# 2                Yes                  23    Credit Card
# 3                Yes                  49         PayPal
# 4                Yes                  31         PayPal
# ...              ...                 ...            ...
# 3895              No                  32          Venmo
# 3896              No                  41  Bank Transfer
# 3897              No                  24          Venmo
# 3898              No                  24          Venmo
# 3899              No                  33          Venmo
#
#      Frequency of Purchases Age_Group Amount_Category
# 0               Fortnightly    Middle          Medium
# 1               Fortnightly     Young          Medium
# 2                    Weekly    Middle            High
# 3                    Weekly     Young            High
# 4                  Annually    Middle          Medium
# ...                     ...       ...             ...
# 3895                 Weekly     Adult             Low
# 3896              Bi-Weekly    Middle          Medium
# 3897              Quarterly    Middle          Medium
# 3898                 Weekly    Middle            High
# 3899              Quarterly    Middle            High
#
# [3900 rows x 20 columns]

# %%
amount_encoded=pd.get_dummies(df["Amount_Category"])
amount_encoded
# Out:
#        High    Low  Medium
# 0     False  False    True
# 1     False  False    True
# 2      True  False   False
# 3      True  False   False
# 4     False  False    True
# ...     ...    ...     ...
# 3895  False   True   False
# 3896  False  False    True
# 3897  False  False    True
# 3898   True  False   False
# 3899   True  False   False
#
# [3900 rows x 3 columns]

# %%
season_encoded=pd.get_dummies(df["Season"])
season_encoded
# Out:
#        Fall  Spring  Summer  Winter
# 0     False   False   False    True
# 1     False   False   False    True
# 2     False    True   False   False
# 3     False    True   False   False
# 4     False    True   False   False
# ...     ...     ...     ...     ...
# 3895  False   False    True   False
# 3896  False    True   False   False
# 3897  False    True   False   False
# 3898  False   False    True   False
# 3899  False    True   False   False
#
# [3900 rows x 4 columns]

# %%
df["Combined"]=df["Purchase Amount (USD)"]/df["Age"]
df["Combined"]
# Out:
# 0       0.963636
# 1       3.368421
# 2       1.460000
# 3       4.285714
# 4       1.088889
#           ...
# 3895    0.700000
# 3896    0.942308
# 3897    0.717391
# 3898    1.750000
# 3899    1.557692
# Name: Combined, Length: 3900, dtype: float64

# %%
df["Customer_Score"]=df["Review Rating"]*df["Previous Purchases"]
df["Customer_Score"]
# Out:
# 0        43.4
# 1         6.2
# 2        71.3
# 3       171.5
# 4        83.7
#         ...
# 3895    134.4
# 3896    184.5
# 3897     69.6
# 3898     91.2
# 3899    102.3
# Name: Customer_Score, Length: 3900, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
df["Age_Scaled"]=scaler.fit_transform(df[["Age"]])
df["PurchaseAmount_Scaled"]=scaler.fit_transform(df[["Purchase Amount (USD)"]])
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# 2                        73  Massachusetts    S     Maroon  Spring  ...
# 3                        90   Rhode Island    M     Maroon  Spring  ...
# 4                        49         Oregon    M  Turquoise  Spring  ...
# ...                     ...            ...  ...        ...     ...  ...
# 3895                     28       Virginia    L  Turquoise  Summer  ...
# 3896                     49           Iowa    L      White  Spring  ...
# 3897                     33     New Jersey    L      Green  Spring  ...
# 3898                     77      Minnesota    S      Brown  Summer  ...
# 3899                     81     California    M      Beige  Spring  ...
#
#       Promo Code Used Previous Purchases Payment Method  \
# 0                 Yes                 14          Venmo
# 1                 Yes                  2           Cash
# 2                 Yes                 23    Credit Card
# 3                 Yes                 49         PayPal
# 4                 Yes                 31         PayPal
# ...               ...                ...            ...
# 3895               No                 32          Venmo
# 3896               No                 41  Bank Transfer
# 3897               No                 24          Venmo
# 3898               No                 24          Venmo
# 3899               No                 33          Venmo
#
#      Frequency of Purchases Age_Group  Amount_Category  Combined  \
# 0               Fortnightly    Middle           Medium  0.963636
# 1               Fortnightly     Young           Medium  3.368421
# 2                    Weekly    Middle             High  1.460000
# 3                    Weekly     Young             High  4.285714
# 4                  Annually    Middle           Medium  1.088889
# ...                     ...       ...              ...       ...
# 3895                 Weekly     Adult              Low  0.700000
# 3896              Bi-Weekly    Middle           Medium  0.942308
# 3897              Quarterly    Middle           Medium  0.717391
# 3898                 Weekly    Middle             High  1.750000
# 3899              Quarterly    Middle             High  1.557692
#
#      Customer_Score Age_Scaled PurchaseAmount_Scaled
# 0              43.4   0.711538                0.4125
# 1               6.2   0.019231                0.5500
# 2              71.3   0.615385                0.6625
# 3             171.5   0.057692                0.8750
# 4              83.7   0.519231                0.3625
# ...             ...        ...                   ...
# 3895          134.4   0.423077                0.1000
# 3896          184.5   0.653846                0.3625
# 3897           69.6   0.538462                0.1625
# 3898           91.2   0.500000                0.7125
# 3899          102.3   0.653846                0.7625
#
# [3900 rows x 24 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
df["Age_Std"]=scaler.fit_transform(df[["Age"]])
df["PurchaseAmount_Std"]=scaler.fit_transform(df[["Purchase Amount (USD)"]])
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  ...  \
# 0                        53       Kentucky    L       Gray  Winter  ...
# 1                        64          Maine    L     Maroon  Winter  ...
# 2                        73  Massachusetts    S     Maroon  Spring  ...
# 3                        90   Rhode Island    M     Maroon  Spring  ...
# 4                        49         Oregon    M  Turquoise  Spring  ...
# ...                     ...            ...  ...        ...     ...  ...
# 3895                     28       Virginia    L  Turquoise  Summer  ...
# 3896                     49           Iowa    L      White  Spring  ...
# 3897                     33     New Jersey    L      Green  Spring  ...
# 3898                     77      Minnesota    S      Brown  Summer  ...
# 3899                     81     California    M      Beige  Spring  ...
#
#       Payment Method Frequency of Purchases Age_Group Amount_Category  \
# 0              Venmo            Fortnightly    Middle          Medium
# 1               Cash            Fortnightly     Young          Medium
# 2        Credit Card                 Weekly    Middle            High
# 3             PayPal                 Weekly     Young            High
# 4             PayPal               Annually    Middle          Medium
# ...              ...                    ...       ...             ...
# 3895           Venmo                 Weekly     Adult             Low
# 3896   Bank Transfer              Bi-Weekly    Middle          Medium
# 3897           Venmo              Quarterly    Middle          Medium
# 3898           Venmo                 Weekly    Middle            High
# 3899           Venmo              Quarterly    Middle            High
#
#       Combined  Customer_Score Age_Scaled PurchaseAmount_Scaled   Age_Std  \
# 0     0.963636            43.4   0.711538                0.4125  0.718913
# 1     3.368421             6.2   0.019231                0.5500 -1.648629
# 2     1.460000            71.3   0.615385                0.6625  0.390088
# 3     4.285714           171.5   0.057692                0.8750 -1.517099
# 4     1.088889            83.7   0.519231                0.3625  0.061263
# ...        ...             ...        ...                   ...       ...
# 3895  0.700000           134.4   0.423077                0.1000 -0.267563
# 3896  0.942308           184.5   0.653846                0.3625  0.521618
# 3897  0.717391            69.6   0.538462                0.1625  0.127028
# 3898  1.750000            91.2   0.500000                0.7125 -0.004502
# 3899  1.557692           102.3   0.653846                0.7625  0.521618
#
#      PurchaseAmount_Std
# 0             -0.285629
# 1              0.178852
# 2              0.558882
# 3              1.276716
# 4             -0.454531
# ...                 ...
# 3895          -1.341267
# 3896          -0.454531
# 3897          -1.130139
# 3898           0.727784
# 3899           0.896686
#
# [3900 rows x 26 columns]

# %%
df.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# Age_Group                 0
# Amount_Category           0
# Combined                  0
# Customer_Score            0
# Age_Scaled                0
# PurchaseAmount_Scaled     0
# Age_Std                   0
# PurchaseAmount_Std        0
# dtype: int64

# %%
df.to_csv("shopping_trends_updated_feature_enginnering.csv",index=False)

# %%
print("Feature Enginnering and Salling Completed !")
# Out:
# Feature Enginnering and Salling Completed !
